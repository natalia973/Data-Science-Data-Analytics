# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia973/Data-Science-Data-Analytics/blob/main/Gr%C3%A1ficosPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn

# %%
df=pd.read_csv('/content/insect.csv')
df.shape
#Possui 72 linhas e 2 colunas
dados = pd.read_csv('/content/trees.csv')

# %%
dados.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
agrupado = df.groupby(['spray'])['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar(color = ['blue' , 'pink' , 'green' , 'red' , 'yellow' , 'gray'])
# Out:
# <Axes: xlabel='spray'>

# %%
#Gráfico de pizza, bom porque tem poucas categorias.
plt.figure(figsize=(7, 7))
plt.pie(
    agrupado,
    labels = agrupado.index,
    autopct = '%1.1f%%',
    startangle = 140
)
plt.title('Gráfico em porcentagens')

plt.show()

# %%
#Visualização do boxplot utilizando srn
#orient é se é na vertical ou horizontal
srn.boxplot(data=dados.Volume , orient='v').set_title('árvores')
# Out:
# Text(0.5, 1.0, 'árvores')

# %%
srn.boxplot(data = dados)
#Visualização do boxplot de todas as colunas.
#O ponto representa um outlier, valor fora do padrão.
# Out:
# <Axes: >

# %%
srn.histplot(dados.Volume, stat = "density" , color = 'red' , kde = True , bins = 10).set(title='Volume')
# Out:
# [Text(0.5, 1.0, 'Volume')]

# %%
base2 = pd.read_csv('/content/chicken.csv')
agrupado = base2.groupby('feed')[('weight')].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
#Agrupando valores da coluna feed
teste = base2.loc[base2['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
teste2 = base2.loc[base2['feed'] == 'horsebean']
teste3 = base2.loc[base2['feed'] == 'casein']
teste4 = base2.loc[base2['feed'] == 'sunflower']

# %%
#Histograma
srn.kdeplot(base2.loc[base2['feed'] == 'horsebean'].weight).set(title='horsebean')
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
#Histograma considerando apenas o valor casein:
'''srn = de onde importou
base2.loc - filtra a coluna e o valor
weight -eixo x
kde = True - terá a linha de densidade'''
srn.histplot(base2.loc[base2["feed"] == 'casein'].weight, kde=True, color = 'gray').set(title='casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
#Agora com 'sunflower'
srn.histplot(base2.loc[base2['feed'] == 'sunflower']. weight, kde = True, color = 'green').set(title ='Sunflower')
# Out:
# [Text(0.5, 1.0, 'Sunflower')]

# %%
srn.histplot(base2.loc[base2['feed'] == 'linseed'].weight , kde=True, color='purple').set(title='linseed')
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
plt.figure()
plt.subplot(3,2,1)
srn.histplot(base2.loc[base2['feed'] == 'horsebean'].weight , kde = True , color='pink').set(title = 'HorseBean')
plt.subplot(3,2,2)
srn.histplot(base2.loc[base2['feed'] == 'casein'].weight , kde = True , color='brown').set(title = 'Casein')
plt.subplot(3,2,3)
srn.histplot(base2.loc[base2['feed'] == 'linseed'].weight , kde = True , color='blue').set(title = 'Linseed')
plt.subplot(3,2,4)
srn.histplot(base2.loc[base2['feed'] == 'meatmeal'].weight , kde = True , color= 'gray').set(title = 'Meatmeal')
plt.subplot(3,2,5)
srn.histplot(base2.loc[base2['feed'] == 'soybean'].weight , kde = True , color = 'red').set(title = 'soybean')
plt.subplot(3,2,6)
srn.histplot(base2.loc[base2['feed'] == 'sunflower'].weight , kde = True, color='green').set(title = 'sunflower')
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
dados2 = pd.read_csv('/content/co2.csv')
dados2.head()
# Out:
#   Plant    Type   Treatment  conc  uptake
# 0   Qn1  Quebec  nonchilled    95    16.0
# 1   Qn1  Quebec  nonchilled   175    30.4
# 2   Qn1  Quebec  nonchilled   250    34.8
# 3   Qn1  Quebec  nonchilled   350    37.2
# 4   Qn1  Quebec  nonchilled   500    35.3

# %%
#Gráfico de dispersão do conc e uptake agrupados(hue) pelo Type
srn.scatterplot(x = dados2['conc' ], y = dados2['uptake'], hue='Type', data = dados2)
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
#Seleção de registros específicos, do type:
m = dados2.loc[dados2['Type'] == 'Quebec']
n = dados2.loc[dados2['Type'] == 'Mississippi']
ax1 = srn.scatterplot( x = m.conc , y=m.uptake)
ax1.set_title('Quebec')
ax2=srn.scatterplot(x = n.conc , y = n.uptake)
ax2.set_title('Mississippi')
# Out:
# Text(0.5, 1.0, 'Mississippi')

# %%
#Subgráficos, 1 linha e duas colunas mostrando os dados de cada
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
ax1 = srn.scatterplot( x = m.conc , y=m.uptake)
ax1.set_title('Quebec')
plt.subplot(1,2,2)
ax2=srn.scatterplot(x = n.conc , y = n.uptake)
ax2.set_title('Mississippi')
plt.tight_layout()
plt.show()

# %%
#Gráfico de dispersão para chilled e não chilled
q=dados2.loc[dados2["Treatment"] == 'chilled']
r=dados2.loc[dados2["Treatment"] == 'nonchilled']
ax3 = srn.scatterplot(x= q.conc , y = q.uptake)
ax3.set_title('chilled')
ax4 = srn.scatterplot(x = r.conc , y = r.uptake)
ax4.set_title('nonchilled')
# Out:
# Text(0.5, 1.0, 'nonchilled')

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
ax3 = srn.scatterplot(x= q.conc , y = q.uptake, color='green')
ax3.set_title('chilled')
plt.subplot(1,2,2)
ax4 = srn.scatterplot(x = r.conc , y = r.uptake)
ax4.set_title('nonchilled')
# Out:
# Text(0.5, 1.0, 'nonchilled')

# %%
n = pd.read_csv('/content/esoph.csv')
srn.catplot(x = 'alcgp' , y = 'ncontrols' , data = n ,  col = 'tobgp')
