# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia973/Data-Science-Data-Analytics/blob/main/Gr%C3%A1ficosPython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv("/content/trees.csv")
base = pd.read_csv('/content/co2.csv')
dados.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
h = np.histogram(dados.iloc[:,1] , bins = 6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
plt.hist(dados.iloc[:,1], bins=6)
#iloc localiza com base nas linhas e colunas
plt.title("árvores")
plt.xlabel("Altura")
plt.ylabel("Frquência")
# Out:
# Text(0, 0.5, 'Frquência')

# %%
#Histograma com divisão de frequência:
#kde é linha de densidade
sns.histplot(dados.iloc[:,1] , bins = 6 , kde = False , color = 'blue').set(title = "Árvores")
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
sns.kdeplot(dados.iloc[:,1] , color='blue').set(title = "Árvores")
# Out:
# [Text(0.5, 1.0, 'Árvores')]

# %%
sns.histplot(dados.iloc[:,1] , kde=True , color='blue' , bins = 6).set(title = 'árvore')
#kde é True por que apresenta linha de densidade
# Out:
# [Text(0.5, 1.0, 'árvore')]

# %%
plt.scatter(x = dados.Girth , y = dados.Volume , color='blue' , facecolors = 'none' , marker = '*')

# %%
plt.plot(dados.Girth, dados.Volume)

# %%
sns.regplot(x = dados.Girth , y = dados.Volume , data = dados , x_jitter = 0.3 , fit_reg=False)
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %%
base.head()
#definir os eixos x e y:
x = base.conc
y = base.uptake

# %%
#Valores únicos da coluna Treatmente
unicos = list(set(base.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
#Fornecer cores diferentes ao gráfico de dispersão:
#Percorre cada valor na coluna Treatment(chilled e nonchilled) e cria um gráfico de dispersão
for i in range(len(unicos)):
  indice = base.Treatment == unicos[i]
  plt.scatter(x[indice] , y[indice] , label = unicos[i])
plt.legend (loc = 'lower right')

# %%
#Gráficos conjuntos em uma mesma tela:
plt.scatter(dados.Girth, dados.Volume)

# %%
plt.scatter(dados.Girth , dados.Height)

# %%
plt.scatter(dados.Height , dados.Volume)

# %%
plt.hist(dados.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
#Colocando os gráficos em somente uma tela:
#Criação de uma figura:
plt.figure(1)
plt.subplot(2,2,1)
plt.scatter(dados.Girth , dados.Height)
plt.subplot(2,2,2)
plt.scatter(dados.Height , dados.Volume , marker= '*')
plt.subplot(2,2,4)
plt.hist(dados.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(dados.Volume , vert = False, showfliers = True ,notch = True, patch_artist = True )
plt.xlabel('árvores')
plt.ylabel('volume')
# Out:
# Text(0, 0.5, 'volume')

# %%
#Agora 3 box plots juntos
plt.boxplot(dados.Height, vert= False)
plt.boxplot(dados.Volume, vert = False)
plt.boxplot(dados.Girth, vert = False)
plt.title('árvores')
plt.xlabel('dados')
# Out:
# Text(0.5, 0, 'dados')
