# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia973/Data-Science-Data-Analytics/blob/main/pandas_exercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Exercícios com `bios.csv`

# %%
import pandas as pd
df=pd.read_csv('/content/bios (1).csv')

# %% [markdown]
# ### Exercício 1
# Mostre os nomes das colunas'

# %% [markdown]
# ### Exercício 2
# Verifique os tipos de dados de cada coluna

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %% [markdown]
# ### Exercício 4
# Conte quantos valores nulos existem em cada coluna

# %%
df.isnull().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm            0
# weight_kg        43430
# died_date       111560
# imc              43430
# dtype: int64

# %% [markdown]
# ### Exercício 5
# Copie o dataframe sem os valores nulos

# %%
df2 = df.dropna()
df2
# Out:
#         athlete_id             name   born_date    born_city  \
# 2                3     Jean Borotra  1898-08-13     Biarritz
# 3                4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107            108   Anders Nielsen  1967-02-24    Cape Town
# 258            259   Tonny Maringgi  1959-06-10      Kendari
# 300            301     Jackson Fear  1978-01-13       Sydney
# ...            ...              ...         ...          ...
# 135272      138435        Art Child  1916-09-15     West Ham
# 135277      138440   Toyoko Yoshino  1920-02-12     Abashiri
# 135283      138446   Jacques Demaré  1900-09-01    Vincennes
# 136653      139884  Johanna Bassani  2002-04-25  Vöcklabruck
# 141190      144729    Naonobu Fujii  1992-01-05   Ishinomaki
#
#                  born_region born_country            NOC  height_cm  \
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 3                      Paris          FRA         France      168.0
# 107             Western Cape          RSA  Great Britain      173.0
# 258        Sulawesi Tenggara          INA      Indonesia      167.0
# 300          New South Wales          AUS      Australia      178.0
# ...                      ...          ...            ...        ...
# 135272               England          GBR  Great Britain      180.0
# 135277              Hokkaido          JPN          Japan      159.0
# 135283          Val-de-Marne          FRA         France      185.0
# 136653        Oberösterreich          AUT        Austria      163.0
# 141190                Miyagi          JPN          Japan      183.0
#
#         weight_kg   died_date       imc
# 2            76.0  1994-07-17  0.002269
# 3            64.0  1978-03-20  0.002268
# 107          70.0  2010-07-29  0.002339
# 258          65.0  2019-09-15  0.002331
# 300         125.0  2006-07-21  0.003945
# ...           ...         ...       ...
# 135272       71.0  1996-06-30  0.002191
# 135277       54.0  2015-01-24  0.002136
# 135283       78.0  1935-12-09  0.002279
# 136653       54.0  2020-05-05  0.002032
# 141190       80.0  2023-03-10  0.002389
#
# [10794 rows x 11 columns]

# %% [markdown]
# ### Exercício 6
# Mostre o número de valores únicos em cada coluna

# %%
df.nunique()
# Out:
# athlete_id      145500
# name            142780
# born_date        41279
# born_city        22368
# born_region       2554
# born_country       236
# NOC                696
# height_cm           96
# weight_kg          141
# died_date        20009
# imc               3525
# dtype: int64

# %% [markdown]
# ### Exercício 7
# Liste todas as colunas que contêm dados do tipo object

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['name', 'born_date', 'born_city', 'born_region', 'born_country', 'NOC',
#        'died_date'],
#       dtype='object')

# %% [markdown]
# ### Exercício 8
# Filtre todas as linhas onde a coluna 'height' > 180

# %%
df.loc[df['height_cm'] > 180]
# Out:
#         athlete_id               name   born_date        born_city  \
# 1                2     Arnaud Boetsch  1969-04-01           Meulan
# 2                3       Jean Borotra  1898-08-13         Biarritz
# 5                6  Nicolas Chatelain  1970-01-13           Amiens
# 16              17         Guy Forget  1965-01-04       Casablanca
# 25              26      Henri Leconte  1963-07-04          Lillers
# ...            ...                ...         ...              ...
# 145465      149192  Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193     Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195  Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200     Toms Andersons  1993-11-25             Rīga
# 145494      149221      George Wright  1890-07-21          Toronto
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 5                      Somme          FRA         France      181.0
# 16         Casablanca-Settat          MAR         France      189.0
# 25             Pas-de-Calais          FRA         France      184.0
# ...                      ...          ...            ...        ...
# 145465                Moskva          RUS            ROC      188.0
# 145466           Nordjylland          DEN        Denmark      184.0
# 145468              Michigan          USA  United States      187.0
# 145473                  Rīga          LAT         Latvia      185.0
# 145494               Ontario          CAN         Canada      183.0
#
#         weight_kg   died_date       imc
# 1            76.0         NaN  0.002269
# 2            76.0  1994-07-17  0.002269
# 5            70.0         NaN  0.002137
# 16           79.0         NaN  0.002212
# 25           78.0         NaN  0.002304
# ...           ...         ...       ...
# 145465       82.0         NaN  0.002320
# 145466       81.0         NaN  0.002392
# 145468       97.0         NaN  0.002774
# 145473       86.0         NaN  0.002513
# 145494        NaN  1973-01-28       NaN
#
# [35368 rows x 11 columns]

# %% [markdown]
# ### Exercício 9
# Calcule o desvio padrão da coluna 'height'

# %%
df['height_cm'].std()
# Out:
# 8.887089781136993

# %% [markdown]
# ### Exercício 10
# Encontre o valor mínimo e máximo de 'weight'

# %%
df['height_cm'].min()
# Out:
# 127.0

# %%
df['height_cm'].max()
# Out:
# 226.0

# %% [markdown]
# ### Exercício 11
# Crie uma nova coluna chamada 'imc'

# %%
df['imc'] = df['weight_kg'] / df['height_cm'] ** 2
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# 0                    Gironde          FRA     France  176.333724        NaN
# 1                   Yvelines          FRA     France  183.000000       76.0
# 2       Pyrénées-Atlantiques          FRA     France  183.000000       76.0
# 3                      Paris          FRA     France  168.000000       64.0
# 4                    England          GBR     France  176.333724        NaN
# ...                      ...          ...        ...         ...        ...
# 145495            Sverdlovsk          RUS        ROC  167.000000       61.0
# 145496                Moskva          RUS        ROC  168.000000       65.0
# 145497           Arkhangelsk          RUS        ROC  163.000000       55.0
# 145498           Deux-Sèvres          FRA     France  166.000000        NaN
# 145499       New South Wales          AUS  Australia  176.333724        NaN
#
#          died_date       imc
# 0       1960-10-02       NaN
# 1              NaN  0.002269
# 2       1994-07-17  0.002269
# 3       1978-03-20  0.002268
# 4       1930-07-25       NaN
# ...            ...       ...
# 145495         NaN  0.002187
# 145496         NaN  0.002303
# 145497         NaN  0.002070
# 145498  1986-03-18       NaN
# 145499  2003-10-20       NaN
#
# [145500 rows x 11 columns]

# %% [markdown]
# ### Exercício 12
# Arredonde a coluna 'imc'

# %%
df['imc'].round(6)
# Out:
# 0              NaN
# 1         0.002269
# 2         0.002269
# 3         0.002268
# 4              NaN
#             ...
# 145495    0.002187
# 145496    0.002303
# 145497    0.002070
# 145498         NaN
# 145499         NaN
# Name: imc, Length: 145500, dtype: float64

# %% [markdown]
# ### Exercício 13
# Preencha altura nula com a média

# %%
df['height_cm']=df['height_cm'].fillna(df['height_cm'].mean())
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# 0                    Gironde          FRA     France  176.333724        NaN
# 1                   Yvelines          FRA     France  183.000000       76.0
# 2       Pyrénées-Atlantiques          FRA     France  183.000000       76.0
# 3                      Paris          FRA     France  168.000000       64.0
# 4                    England          GBR     France  176.333724        NaN
# ...                      ...          ...        ...         ...        ...
# 145495            Sverdlovsk          RUS        ROC  167.000000       61.0
# 145496                Moskva          RUS        ROC  168.000000       65.0
# 145497           Arkhangelsk          RUS        ROC  163.000000       55.0
# 145498           Deux-Sèvres          FRA     France  166.000000        NaN
# 145499       New South Wales          AUS  Australia  176.333724        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %% [markdown]
# ### Exercício 14
# Verifique duplicatas

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 145495    False
# 145496    False
# 145497    False
# 145498    False
# 145499    False
# Length: 145500, dtype: bool

# %% [markdown]
# ### Exercício 15
# Remova duplicatas

# %%
df.drop_duplicates()
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# 0                    Gironde          FRA     France        NaN        NaN
# 1                   Yvelines          FRA     France      183.0       76.0
# 2       Pyrénées-Atlantiques          FRA     France      183.0       76.0
# 3                      Paris          FRA     France      168.0       64.0
# 4                    England          GBR     France        NaN        NaN
# ...                      ...          ...        ...        ...        ...
# 145495            Sverdlovsk          RUS        ROC      167.0       61.0
# 145496                Moskva          RUS        ROC      168.0       65.0
# 145497           Arkhangelsk          RUS        ROC      163.0       55.0
# 145498           Deux-Sèvres          FRA     France      166.0        NaN
# 145499       New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 0       1960-10-02
# 1              NaN
# 2       1994-07-17
# 3       1978-03-20
# 4       1930-07-25
# ...            ...
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20
#
# [145500 rows x 10 columns]

# %% [markdown]
# ### Exercício 16
# Quantos têm peso acima da média

# %%
df.loc[df['weight_kg'] > df['weight_kg'].mean()]
# Out:
#         athlete_id                  name   born_date        born_city  \
# 1                2        Arnaud Boetsch  1969-04-01           Meulan
# 2                3          Jean Borotra  1898-08-13         Biarritz
# 6                7         Patrick Chila  1969-11-27      Ris-Orangis
# 16              17            Guy Forget  1965-01-04       Casablanca
# 17              18  Jean-Philippe Gatien  1968-10-16             Alès
# ...            ...                   ...         ...              ...
# 145464      149191       Joonas Nättinen  1991-01-03            Jämsä
# 145465      149192     Stanislav Galiyev  1992-01-17  Moskva (Moscow)
# 145466      149193        Mikkel Aagaard  1995-10-18    Frederikshavn
# 145468      149195     Justin Abdelkader  1987-02-25         Muskegon
# 145473      149200        Toms Andersons  1993-11-25             Rīga
#
#                  born_region born_country            NOC  height_cm  \
# 1                   Yvelines          FRA         France      183.0
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 6                    Essonne          FRA         France      180.0
# 16         Casablanca-Settat          MAR         France      189.0
# 17                      Gard          FRA         France      178.0
# ...                      ...          ...            ...        ...
# 145464           Keski-Suomi          FIN        Finland      189.0
# 145465                Moskva          RUS            ROC      188.0
# 145466           Nordjylland          DEN        Denmark      184.0
# 145468              Michigan          USA  United States      187.0
# 145473                  Rīga          LAT         Latvia      185.0
#
#         weight_kg   died_date
# 1            76.0         NaN
# 2            76.0  1994-07-17
# 6            73.0         NaN
# 16           79.0         NaN
# 17           73.0         NaN
# ...           ...         ...
# 145464       90.0         NaN
# 145465       82.0         NaN
# 145466       81.0         NaN
# 145468       97.0         NaN
# 145473       86.0         NaN
#
# [49081 rows x 10 columns]

# %% [markdown]
# ### Exercício 17
# Correlação entre variáveis

# %%
df.corr(numeric_only = True)
# Out:
#             athlete_id  height_cm  weight_kg
# athlete_id    1.000000  -0.000378   0.005498
# height_cm    -0.000378   1.000000   0.779290
# weight_kg     0.005498   0.779290   1.000000

# %% [markdown]
# ### Exercício 18
# Pessoa mais alta

# %%
df.loc[df['height_cm'].max(),'name']
# Out:
# 'Ede Tóth'

# %% [markdown]
# ### Exercício 19
# Nome em minúsculas

# %%
df['name'].str.lower()
# Out:
# 0         jean-françois blanchy
# 1                arnaud boetsch
# 2                  jean borotra
# 3               jacques brugnon
# 4                  albert canet
#                   ...
# 145495        polina luchnikova
# 145496      valeriya merkusheva
# 145497          yuliya smirnova
# 145498           andré foussard
# 145499            bill phillips
# Name: name, Length: 145500, dtype: object

# %% [markdown]
# ### Exercício 20
# Número de letras do nome

# %%
df['quantidade_letras'] = df['name'].str.len()

# %% [markdown]
# ### Exercício 21
# Últimas 5 linhas

# %%
df.tail(5)
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %% [markdown]
# ### Exercício 27
# Salve novo CSV
