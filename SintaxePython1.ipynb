# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia973/Data-Science-Data-Analytics/blob/main/SintaxePython1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dados = [['Natália' , 23 , 'BA'] , ['João' , 34 , 'SE'] , ['Matheus' , 50 , 'CE']]
colunas = ['Nome' , 'Cidade' , 'Estado']
df = pd.DataFrame(data = dados , columns= colunas)
df
# Out:
#       Nome  Cidade Estado
# 0  Natália      23     BA
# 1     João      34     SE
# 2  Matheus      50     CE

# %%
dados = {
    "nomes" : ['Jovanda' , 'Jorge' , 'Natália'],
    "idade" : [43 , 67 , 23],
    "estado" : ['BA' , 'SE' , 'SP']
}
df = pd.DataFrame(data = dados)
df
# Out:
#      nomes  idade estado
# 0  Jovanda     43     BA
# 1    Jorge     67     SE
# 2  Natália     23     SP

# %%
df = pd.read_csv('/content/results.csv' , sep = ",")
df.head()
# Out:
# /tmp/ipython-input-1598073669.py:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/results.csv' , sep = ",")
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# ...

# %%
df.shape
#Exibe a quantidade de linhas e colunas
# Out:
# (308408, 11)

# %%
df['noc'].unique()
#Exibe a qtd de países que são únicos
# Out:
# array(['FRA', 'GBR', 'FRG', 'GER', 'GHA', 'GRE', 'GUA', 'HAI', 'HKG',
#        'HUN', 'TKM', 'INA', 'AUT', 'NED', 'IND', 'ARG', 'AUS', 'BEL',
#        'BHU', 'BLR', 'BRA', 'BUL', 'CAN', 'CHN', 'COL', 'CRC', 'CYP',
#        'DEN', 'ESP', 'EST', 'FIN', 'EUN', 'GEO', 'USA', 'GUM', 'ARM',
#        'BAH', 'BER', 'BIH', 'URS', 'BOH', 'TCH', 'CHI', 'TPE', 'IRI',
#        'IRL', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KOR',
#        'KSA', 'KUW', 'LAT', 'LBA', 'LBN', 'LTU', 'LUX', 'MAD', 'MAR',
#        'MAS', 'MRI', 'MEX', 'NGR', 'NOR', 'NZL', 'PAK', 'PAR', 'PER',
#        'PHI', 'POL', 'BUR', 'CAF', 'CAM', 'CGO', 'EGY', 'CHA', 'CIV',
#        'CMR', 'COK', 'PUR', 'CUB', 'DOM', 'CRO', 'CZE', 'BEN', 'ECU',
#        'UAR', 'ESA', 'KAZ', 'KEN', 'MDA', 'MGL', 'MLT', 'MON', 'POR',
#        'PRK', 'ROU', 'RSA', 'RUS', 'SLO', 'SMR', 'SOL', 'SUI', 'SWE',
#        'THA', 'TUR', 'UKR', 'YUG', 'ZIM', 'ALG', 'QAT', 'SGP', 'SRI',
# ...

# %%
df.sample(5,random_state= 10)
#Amostragem aleatória de 5 elementos
# Out:
#           year    type                        discipline  \
# 280828  2016.0  Summer  Artistic Gymnastics (Gymnastics)
# 271344  2012.0  Summer                     Weightlifting
# 28917   1972.0  Summer            Cycling Road (Cycling)
# 172045  1994.0  Winter            Alpine Skiing (Skiing)
# 208707  1976.0  Winter                              Luge
#
#                                          event               as  athlete_id  \
# 280828  Individual All-Around, Women (Olympic)  Seda Tutkhalyan      131579
# 271344        Light-Heavyweight, Men (Olympic)  Mikalai Novikau      127169
# 28917     Road Race, Individual, Men (Olympic)     Tomás Nistal       15889
# 172045                Super G, Women (Olympic)   Jeanette Lunde       81718
# 208707                  Singles, Men (Olympic)  Shieh Wei-Cheng       97492
#
#         noc team  place   tied medal
# 280828  RUS  NaN   22.0  False   NaN
# 271344  BLR  NaN    NaN  False   NaN
# 28917   ESP  NaN   54.0  False   NaN
# ...

# %%
df['noc'].nunique()
#Há 230 valores únicos para os países
# Out:
# 230

# %%
df.loc[4]
#Informações da linha 4
# Out:
# year                          1920.0
# type                          Summer
# discipline                    Tennis
# event         Doubles, Men (Olympic)
# as             Jean-François Blanchy
# athlete_id                         1
# noc                              FRA
# team                 Jacques Brugnon
# place                            4.0
# tied                           False
# medal                            NaN
# Name: 4, dtype: object

# %%
df.loc[0:5]
# Exibe informações da linha 0 até a linha 5
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 5  1996.0  Summer     Tennis    Singles, Men (Olympic)         Arnaud Boetsch
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN
# 5           2  FRA              NaN   17.0   True   NaN

# %%
df.loc[[2,5,10]]
#Linhas 2,5 e 10 selecionadas
# Out:
#       year    type discipline                   event                     as  \
# 2   1920.0  Summer     Tennis  Singles, Men (Olympic)  Jean-François Blanchy
# 5   1996.0  Summer     Tennis  Singles, Men (Olympic)         Arnaud Boetsch
# 10  1920.0  Summer     Tennis  Singles, Men (Olympic)        Jacques Brugnon
#
#     athlete_id  noc team  place  tied medal
# 2            1  FRA  NaN   32.0  True   NaN
# 5            2  FRA  NaN   17.0  True   NaN
# 10           4  FRA  NaN    9.0  True   NaN

# %%
df.loc[1:10 , ['as' , 'event' , 'year']]
#Exibe as colunas as, event e year, das linhas de 1 até 10
# Out:
#                        as                     event    year
# 1   Jean-François Blanchy    Doubles, Men (Olympic)  1912.0
# 2   Jean-François Blanchy    Singles, Men (Olympic)  1920.0
# 3   Jean-François Blanchy  Doubles, Mixed (Olympic)  1920.0
# 4   Jean-François Blanchy    Doubles, Men (Olympic)  1920.0
# 5          Arnaud Boetsch    Singles, Men (Olympic)  1996.0
# 6          Arnaud Boetsch    Doubles, Men (Olympic)  1996.0
# 7            Jean Borotra    Singles, Men (Olympic)  1924.0
# 8            Jean Borotra  Doubles, Mixed (Olympic)  1924.0
# 9            Jean Borotra    Doubles, Men (Olympic)  1924.0
# 10        Jacques Brugnon    Singles, Men (Olympic)  1920.0

# %%
df.iloc[1:11,[0,1]]
#Linhas de index 1 a 11, e colunas do index de 0 a 1.
# Out:
#       year    type
# 1   1912.0  Summer
# 2   1920.0  Summer
# 3   1920.0  Summer
# 4   1920.0  Summer
# 5   1996.0  Summer
# 6   1996.0  Summer
# 7   1924.0  Summer
# 8   1924.0  Summer
# 9   1924.0  Summer
# 10  1920.0  Summer

# %%
df.info()
#Nomes de colunas e os tipos de variáveis nelas.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
df.describe()
#Exibe dados estaísticos sobre a tabela.
# Out:
#                 year     athlete_id          place
# count  114059.000000  114944.000000  108242.000000
# mean     1965.579411   27715.716279      18.433242
# std        27.432009   14395.917151      23.998373
# min      1896.000000       1.000000       1.000000
# 25%      1952.000000   15801.750000       4.000000
# 50%      1972.000000   29216.000000       9.000000
# 75%      1988.000000   40526.000000      22.000000
# max      2020.000000   51563.000000     185.000000

# %%
for index, row in df.iterrows():
  print(index)
  print(row)
  #Não é recomendado usar loops em dataframes.
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# athlete_id                         8714.0
# noc                                   USA
# team                                  NaN
# place                                 4.0
# tied                                False
# medal                                 NaN
# Name: 13236, dtype: object
# 13237
# year                            1936.0
# type                            Summer
# discipline                      Boxing
# event         Flyweight, Men (Olympic)
# as                          Lou Laurie
# athlete_id                      8715.0
# noc                                USA
# team                               NaN
# place                              3.0
# tied                             False
# medal                           Bronze
# Name: 13237, dtype: object
# 13238
# year                               1924.0
# type                               Summer
# discipline                         Boxing
# ...

# %%
df.sort_values(['year'])
#Aqui exibe a coluna 'year' em ordem crescente(quando não é especificado)
# Out:
#           year    type                        discipline  \
# 64462   1896.0  Summer  Artistic Gymnastics (Gymnastics)
# 64461   1896.0  Summer  Artistic Gymnastics (Gymnastics)
# 64460   1896.0  Summer  Artistic Gymnastics (Gymnastics)
# 64459   1896.0  Summer  Artistic Gymnastics (Gymnastics)
# 64458   1896.0  Summer  Artistic Gymnastics (Gymnastics)
# ...        ...     ...                               ...
# 114343     NaN     NaN               Swimming (Aquatics)
# 114929     NaN     NaN               Swimming (Aquatics)
# 114930     NaN     NaN               Swimming (Aquatics)
# 114931     NaN     NaN               Swimming (Aquatics)
# 114932     NaN     NaN               Swimming (Aquatics)
#
#                                                     event                as  \
# 64462                                           Athletics       Gyula Kakas
# 64461                      Pommelled Horse, Men (Olympic)       Gyula Kakas
# ...

# %%
df.sort_values(['year'], ascending = False)
#Aqui exibe os valores da coluna year em ordem decrescente.
# Out:
#           year    type                        discipline  \
# 88809   2020.0  Summer                          Shooting
# 20580   2020.0  Summer  Equestrian Dressage (Equestrian)
# 20579   2020.0  Summer  Equestrian Dressage (Equestrian)
# 88470   2020.0  Summer                          Shooting
# 20348   2020.0  Summer   Equestrian Jumping (Equestrian)
# ...        ...     ...                               ...
# 114343     NaN     NaN               Swimming (Aquatics)
# 114929     NaN     NaN               Swimming (Aquatics)
# 114930     NaN     NaN               Swimming (Aquatics)
# 114931     NaN     NaN               Swimming (Aquatics)
# 114932     NaN     NaN               Swimming (Aquatics)
#
#                                                     event                as  \
# 88809                                Skeet, Men (Olympic)    Moustafa Hamdy
# 20580                                Team, Open (Olympic)       Carl Hester
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=114945, step=1)

# %%
df.sort_values(['year' , 'as'], ascending=[1,0])
#1- crescente - year
#0 - decrescente - as
#A tabela na coluna 'year' será crescente(1) , a tabela na coluna 'as' será decrescente(0)
# Out:
#          year    type                        discipline  \
# 90765  1896.0  Summer                          Shooting
# 90766  1896.0  Summer                          Shooting
# 88578  1896.0  Summer                         Athletics
# 88579  1896.0  Summer                         Athletics
# 88580  1896.0  Summer                         Athletics
# ...       ...     ...                               ...
# 19251     NaN     NaN  Equestrian Eventing (Equestrian)
# 19416     NaN     NaN  Equestrian Eventing (Equestrian)
# 19417     NaN     NaN  Equestrian Eventing (Equestrian)
# 21047     NaN     NaN   Equestrian Jumping (Equestrian)
# 21048     NaN     NaN   Equestrian Jumping (Equestrian)
#
#                                                    event                 as  \
# 90765          Military Pistol, 25 metres, Men (Olympic)  Xenon Michailidis
# 90766  Free Rifle, Any Position, 300 metres, Men (Oly...  Xenon Michailidis
# ...
