# %% [markdown]
# <a href="https://colab.research.google.com/github/natalia973/Data-Science-Data-Analytics/blob/main/pandasCleaningData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Pandas - Exercícios com `bios.csv`

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/sample_data/bios.csv")

# %% [markdown]
# ### Exercício 1
# Mostre os nomes das colunas'

# %%
df.columns.to_list()
# Out:
# ['athlete_id',
#  'name',
#  'born_date',
#  'born_city',
#  'born_region',
#  'born_country',
#  'NOC',
#  'height_cm',
#  'weight_kg',
#  'died_date']

# %% [markdown]
# ### Exercício 2
# Verifique os tipos de dados de cada coluna

# %%
df.dtypes
# Out:
# athlete_id        int64
# name             object
# born_date        object
# born_city        object
# born_region      object
# born_country     object
# NOC              object
# height_cm       float64
# weight_kg       float64
# died_date        object
# dtype: object

# %% [markdown]
# ### Exercício 4
# Conte quantos valores nulos existem em cada coluna

# %%
df.isnull().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm        38849
# weight_kg        43430
# died_date       111560
# dtype: int64

# %% [markdown]
# ### Exercício 5
# Copie o dataframe sem os valores nulos

# %%
df_sem_nulos = df.dropna()
df_sem_nulos
# Out:
#         athlete_id             name   born_date    born_city  \
# 2                3     Jean Borotra  1898-08-13     Biarritz
# 3                4  Jacques Brugnon  1895-05-11  Paris VIIIe
# 107            108   Anders Nielsen  1967-02-24    Cape Town
# 258            259   Tonny Maringgi  1959-06-10      Kendari
# 300            301     Jackson Fear  1978-01-13       Sydney
# ...            ...              ...         ...          ...
# 135272      138435        Art Child  1916-09-15     West Ham
# 135277      138440   Toyoko Yoshino  1920-02-12     Abashiri
# 135283      138446   Jacques Demaré  1900-09-01    Vincennes
# 136653      139884  Johanna Bassani  2002-04-25  Vöcklabruck
# 141190      144729    Naonobu Fujii  1992-01-05   Ishinomaki
#
#                  born_region born_country            NOC  height_cm  \
# 2       Pyrénées-Atlantiques          FRA         France      183.0
# 3                      Paris          FRA         France      168.0
# ...

# %% [markdown]
# ### Exercício 6
# Mostre o número de valores únicos em cada coluna

# %%
df.nunique()
# Out:
# athlete_id      145500
# name            142780
# born_date        41279
# born_city        22368
# born_region       2554
# born_country       236
# NOC                696
# height_cm           95
# weight_kg          141
# died_date        20009
# dtype: int64

# %% [markdown]
# ### Exercício 7
# Liste todas as colunas que contêm dados do tipo object

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['name', 'born_date', 'born_city', 'born_region', 'born_country', 'NOC',
#        'died_date'],
#       dtype='object')

# %% [markdown]
# ### Exercício 8
# Filtre todas as linhas onde a coluna 'height' > 180

# %%
df[df['height_cm'] > 180 ]

# %%
df.query('height_cm > 180')

# %%
df.loc[df['height_cm'] > 180 ]

# %% [markdown]
# ### Exercício 9
# Calcule o desvio padrão da coluna 'height'

# %%
df['height_cm'].std()
# Out:
# 10.380281757520233

# %% [markdown]
# ### Exercício 10
# Encontre o valor mínimo e máximo de 'weight'

# %%
df['height_cm'].min(),df['height_cm'].max()
# Out:
# (127.0, 226.0)

# %% [markdown]
# ### Exercício 11
# Crie uma nova coluna chamada 'imc'

# %%
df['imc'] = df['weight_kg'] / (df['height_cm'] / 100) ** 2
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Exercício 12
# Arredonde a coluna 'imc'

# %%
df['imc'] = df['imc'].round(2)
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Exercício 13
# Preencha altura nula com a média

# %%
df['height_cm'].fillna(df['height_cm'].mean())
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Exercício 14
# Verifique duplicatas

# %%
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# ### Exercício 15
# Remova duplicatas

# %%
df.drop_duplicates()
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Exercício 16
# Quantos têm peso acima da média

# %%
df[df['weight_kg'] > df['weight_kg'].mean()].shape[0]
# Out:
# 49081

# %% [markdown]
# ### Exercício 17
# Correlação entre variáveis

# %%
corr = df.corr(numeric_only=True)
corr
# Out:
#             athlete_id  height_cm  weight_kg       imc
# athlete_id    1.000000  -0.000310   0.005498  0.008394
# height_cm    -0.000310   1.000000   0.779290  0.305614
# weight_kg     0.005498   0.779290   1.000000  0.828709
# imc           0.008394   0.305614   0.828709  1.000000

# %% [markdown]
# ### Exercício 18
# Pessoa mais alta

# %%
gigante = df[df['height_cm'] == df['height_cm'].max() ]
gigante
# Out:
#        athlete_id      name   born_date       born_city born_region  \
# 89070       89782  Yao Ming  1980-09-12  Xuhui District    Shanghai
#
#       born_country                         NOC  height_cm  weight_kg  \
# 89070          CHN  People's Republic of China      226.0      141.0
#
#       died_date    imc
# 89070       NaN  27.61

# %% [markdown]
# ### Exercício 19
# Nome em minúsculas

# %%
df['name_lower'] = df['name'].str.lower()
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC   height_cm  weight_kg  \
# ...

# %% [markdown]
# ### Exercício 20
# Número de letras do nome

# %%
df['name_characters'] = df['name'].str.len()
df

# %% [markdown]
# ### Exercício 21
# Últimas 5 linhas

# %%
df.tail(5)
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC   height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC  167.000000       61.0
# 145496           Moskva          RUS        ROC  168.000000       65.0
# 145497      Arkhangelsk          RUS        ROC  163.000000       55.0
# 145498      Deux-Sèvres          FRA     France  166.000000        NaN
# 145499  New South Wales          AUS  Australia  176.333724        NaN
#
#          died_date    imc           name_lower  name_characters
# ...

# %% [markdown]
# ### Exercício 27
# Salve novo CSV

# %%
df.to_csv("dataframa_novo.csv",index=False)
